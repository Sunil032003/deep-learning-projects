# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunil032003/deep-learning-projects/blob/main/simpleRNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tensorflow numpy -q

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("neisse/scrapped-lyrics-from-6-genres")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'scrapped-lyrics-from-6-genres' dataset.
# Path to dataset files: /kaggle/input/scrapped-lyrics-from-6-genres

# %%
import pandas as pd
import numpy as np

from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
import os

print(os.listdir(path))
# Out:
# ['artists-data.csv', 'lyrics-data.csv']

# %%
df = pd.read_csv(
    os.path.join(path, "lyrics-data.csv")
)

# %%
df.head()
# Out:
#              ALink                            SName  \
# 0  /ivete-sangalo/                            Arerê
# 1  /ivete-sangalo/  Se Eu Não Te Amasse Tanto Assim
# 2  /ivete-sangalo/                      Céu da Boca
# 3  /ivete-sangalo/            Quando A Chuva Passar
# 4  /ivete-sangalo/                     Sorte Grande
#
#                                                SLink  \
# 0                          /ivete-sangalo/arere.html
# 1  /ivete-sangalo/se-eu-nao-te-amasse-tanto-assim...
# 2                     /ivete-sangalo/chupa-toda.html
# 3          /ivete-sangalo/quando-a-chuva-passar.html
# 4                   /ivete-sangalo/sorte-grande.html
#
#                                                Lyric language
# 0  Tudo o que eu quero nessa vida,\nToda vida, é\...       pt
# 1  Meu coração\nSem direção\nVoando só por voar\n...       pt
# 2  É de babaixá!\nÉ de balacubaca!\nÉ de babaixá!...       pt
# 3  Quando a chuva passar\n\nPra quê falar\nSe voc...       pt
# 4  A minha sorte grande foi você cair do céu\nMin...       pt

# %%
df = df.dropna()

df = df.head(200)

text = " ".join(df["Lyric"].astype(str))

print("Total characters:", len(text))
# Out:
# Total characters: 171013

# %%
import re

text = text.lower()

text = re.sub(r'[^a-zA-Z\s]', '', text)

text = re.sub(r'\s+', ' ', text)

print(text[:500])
# Out:
# tudo o que eu quero nessa vida toda vida amar voc amar voc o seu amor como uma chama acesa queima de prazer de prazer eu j falei com deus que no vou te deixar vou te levar pra onde for qualquer lugar j fiz de tudo pra no te perder arer um lobby um hobby um love com voc arer um lobby um hobby um love com voc cai cai cai cai cai pra c hey hey hey tudotudo vai rolar meu corao sem direo voando s por voar sem saber onde chegar sonhando em te encontrar e as estrelas que hoje eu descobri no seu olhar a

# %%
tokenizer = Tokenizer(num_words=5000)

tokenizer.fit_on_texts([text])

total_words = 5000

print("Vocabulary Size:", total_words)
# Out:
# Vocabulary Size: 5000

# %%
words = text.split()

sequences = []

window_size = 5

for i in range(window_size, len(words)):

    seq = words[i-window_size:i+1]

    sequences.append(seq)

print("Total sequences:", len(sequences))
# Out:
# Total sequences: 33167

# %%
print(sequences[0])
print(sequences[1])
print(sequences[2])
print(sequences[3])
print(sequences[4])
# Out:
# ['tudo', 'o', 'que', 'eu', 'quero', 'nessa']
# ['o', 'que', 'eu', 'quero', 'nessa', 'vida']
# ['que', 'eu', 'quero', 'nessa', 'vida', 'toda']
# ['eu', 'quero', 'nessa', 'vida', 'toda', 'vida']
# ['quero', 'nessa', 'vida', 'toda', 'vida', 'amar']

# %%
input_sequences = []

for seq in sequences:

    encoded = tokenizer.texts_to_sequences([" ".join(seq)])[0]

    if len(encoded) == window_size + 1:
        input_sequences.append(encoded)

input_sequences = np.array(input_sequences)

print(input_sequences.shape)
# Out:
# (33167, 6)

# %%
print(input_sequences[0])
print(input_sequences[1])
print(input_sequences[2])
print(input_sequences[3])
print(input_sequences[4])
# Out:
# [ 38   6   1   5  23 203]
# [  6   1   5  23 203  43]
# [  1   5  23 203  43  62]
# [  5  23 203  43  62  43]
# [ 23 203  43  62  43  32]

# %%
X = input_sequences[:, :-1]

y = input_sequences[:, -1]

y = to_categorical(
    y,
    num_classes=total_words
)

print(X.shape)
print(y.shape)
# Out:
# (33167, 5)
# (33167, 5000)

# %%
model = Sequential([

    Embedding(
        input_dim=total_words,
        output_dim=64,
        input_length=window_size
    ),

    SimpleRNN(128),

    Dense(
        total_words,
        activation='softmax'
    )

])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:100: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(
    X,
    y,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)
# Out:
# Epoch 1/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 16s 61ms/step - accuracy: 0.0234 - loss: 6.9021 - val_accuracy: 0.0188 - val_loss: 6.8942
# Epoch 2/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 17s 44ms/step - accuracy: 0.0269 - loss: 6.4194 - val_accuracy: 0.0306 - val_loss: 6.9781
# Epoch 3/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.0419 - loss: 6.0981 - val_accuracy: 0.0357 - val_loss: 6.9368
# Epoch 4/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.0684 - loss: 5.6688 - val_accuracy: 0.0449 - val_loss: 6.9800
# Epoch 5/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 10s 39ms/step - accuracy: 0.0960 - loss: 5.2655 - val_accuracy: 0.0448 - val_loss: 7.0877
# Epoch 6/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - accuracy: 0.1410 - loss: 4.8769 - val_accuracy: 0.0428 - val_loss: 7.1277
# Epoch 7/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 10s 47ms/step - accuracy: 0.1853 - loss: 4.5100 - val_accuracy: 0.0434 - val_loss: 7.1702
# Epoch 8/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - accuracy: 0.2314 - loss: 4.1623 - val_accuracy: 0.0481 - val_loss: 7.2976
# Epoch 9/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 10s 46ms/step - accuracy: 0.2814 - loss: 3.8328 - val_accuracy: 0.0503 - val_loss: 7.3690
# Epoch 10/10
# 208/208 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - accuracy: 0.3317 - loss: 3.5274 - val_accuracy: 0.0482 - val_loss: 7.4577

# %%
def predict_next_word(seed_text):

    token_list = tokenizer.texts_to_sequences(
        [seed_text]
    )[0]

    token_list = token_list[-window_size:]

    token_list = pad_sequences(
        [token_list],
        maxlen=window_size
    )

    predicted = np.argmax(
        model.predict(token_list, verbose=0)
    )

    for word, index in tokenizer.word_index.items():

        if index == predicted:

            return word

    return ""

# %%
def generate_text(seed_text, n_words):

    for _ in range(n_words):

        next_word = predict_next_word(seed_text)

        seed_text += " " + next_word

    return seed_text

# %%
def generate_text(seed_text, n_words):

    for _ in range(n_words):

        next_word = predict_next_word(seed_text)

        seed_text += " " + next_word

    return seed_text


print(generate_text("we will we will", 5))

print(generate_text("hello from the", 5))

print(generate_text("i love you", 5))
# Out:
# we will we will the the is is is
# hello from the bem a love con love
# i love you i i i i you
